# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\pondharshini\appdata\local\programs\python\python312\lib\site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pondharshini\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\pondharshini\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pondharshini\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pondharshini\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in c:\users\pondharshini\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\pondharshini\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\pondharshini\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\pondharshini\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pondharshini\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\pondharshini\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4]

# %%
y=[10,20,25,30]

# %%
plt.plot(x,y)

# %%
plt.show()

# %%
plt.plot(x,y,color='green',linestyle='--',marker='o')

# %%
plt.title('My Plot')
# Out:
# Text(0.5, 1.0, 'My Plot')

# %%
plt.xlabel('X-axis')
# Out:
# Text(0.5, 0, 'X-axis')

# %%
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
x=[1,2,3]

# %%
y1=[1,4,9]

# %%
y2=[1,2,3]

# %%
plt.plot(x,y1,label='Square')

# %%
plt.plot(x,y2,label='Linear')

# %%
plt.legend()
# Out:
# C:\Users\pondharshini\AppData\Local\Temp\ipykernel_8484\4061938096.py:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.show()

# %%
categories=['A','B','c']

# %%
values=[5,7,3]

# %%
plt.bar(categories,values)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.show()

# %%
data=[1,1,2,3,3,3,4,4,5]

# %%
plt.hist(data,bins=5)
# Out:
# (array([2., 1., 3., 2., 1.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.show()

# %%
x=[1,2,3,4]

# %%
y=[10,20,25,30]

# %%
plt.show()

# %%
plt.plot(x,y)

# %%
plt.savefig('plot.png')
